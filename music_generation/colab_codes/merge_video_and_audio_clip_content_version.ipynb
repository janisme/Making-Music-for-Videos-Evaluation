# %%
# !ffmpeg -i *.mp4 -vn -acodec libmp3lame -ab 64k *.mp3
# !rm -rf *.mp4
# !mv *.mp4 *.mp4ac

# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300085.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300088.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300097.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300098.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300110.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300121.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300166.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300175.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300187.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300190.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300191.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300224.mp4
# !wget https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300227.mp4
# Out:
# --2024-04-24 02:16:33--  https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300085.mp4
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 3.163.189.14, 3.163.189.108, 3.163.189.96, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|3.163.189.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2223176 (2.1M) [video/mp4]
# Saving to: ‘Q300085.mp4’
#
# Q300085.mp4         100%[===================>]   2.12M  --.-KB/s    in 0.1s
#
# 2024-04-24 02:16:33 (21.7 MB/s) - ‘Q300085.mp4’ saved [2223176/2223176]
#
# --2024-04-24 02:16:33--  https://dl.fbaipublicfiles.com/video_similarity_challenge/46ef53734a4/dataset_test/queries/Q300088.mp4
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 3.163.189.14, 3.163.189.108, 3.163.189.96, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|3.163.189.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !pip --quiet install ftfy regex tqdm
# !pip --quiet install git+https://github.com/openai/CLIP.git


import torch
import clip
from PIL import Image
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f'Using device: {device}')
model, preprocess = clip.load("ViT-B/32", device=device)
def classify(im, labels):
    image = preprocess(im).unsqueeze(0).to(device)
    text = clip.tokenize(labels).to(device)

    with torch.no_grad():
        image_features = model.encode_image(image)
        text_features = model.encode_text(text)

        logits_per_image, logits_per_text = model(image, text)
        probs = logits_per_image.softmax(dim=-1).cpu().numpy()
    max_prob = 0
    max_label = ""
    for i, label in enumerate(labels):
        # print(f"{labels[i]} = {probs[0,i]*100}%")
        if probs[0,i] > max_prob:
            max_prob = probs[0,i]
            max_label = labels[i]
            max_label_num = i
    return max_label, max_label_num
    # print(f"The most likely label is {max_label} with a probability of {max_prob*100}%")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# Using device: cuda
# 100%|███████████████████████████████████████| 338M/338M [00:08<00:00, 44.2MiB/s]

# %%
import os
import subprocess

# Get the list of mp4 files in the current directory
mp4_files = [f for f in os.listdir() if f.endswith('.mp4')]

# %%
import re

def get_number_from_filename(filename):
  match = re.search(r'\d+', filename)
  if match:
    return int(match.group(0))
  else:
    return 0

sorted_mp4_files = sorted(mp4_files, key=get_number_from_filename)

mp4_files = sorted_mp4_files
# print(sorted_mp4_files)

# %%
# import glob

# mp4_files = glob.glob("*_short.mp4")

print(len(mp4_files))
print(mp4_files)
# Out:
# 13
# ['Q300085.mp4', 'Q300088.mp4', 'Q300097.mp4', 'Q300098.mp4', 'Q300110.mp4', 'Q300121.mp4', 'Q300166.mp4', 'Q300175.mp4', 'Q300187.mp4', 'Q300190.mp4', 'Q300191.mp4', 'Q300224.mp4', 'Q300227.mp4']

# %%
import glob

mp3_files = glob.glob("*.mp3")
sorted_mp3_files = sorted(mp3_files, key=get_number_from_filename)
mp3_files = sorted_mp3_files

print(len(mp3_files))
print(mp3_files)
# Out:
# 13
# ['Q1_10sec.mp3', 'Q2_10sec.mp3', 'Q4_10sec.mp3', 'Q5_10sec.mp3', 'Q13_10sec.mp3', 'Q20_10sec.mp3', 'Q29_10sec.mp3', 'Q39_10sec.mp3', 'Q66_10sec.mp3', 'Q69_10sec.mp3', 'Q77_10sec.mp3', 'Q80_10sec.mp3', 'Q84_10sec.mp3']

# %%
# simple
# labels = [
#     "a man is standing on a rocky cliff overlooking the ocean",
#     "a view of a wetland area with a fence and rocks",
#     "a group of people dressed in blue and white are dancing",
#     "two elephants walking in a zoo enclosure",
#     "a cartoon image of clouds and plants",
#     "elephants in the wild - elephant stock videos & royalty-free footage",
#     "lavender flowers in the garden",
#     "black and white photo of a mountain range",
#     "yellowstone national park's most famous geyser erupts",
#     "the olympic stadium is lit up at night",
#     "a group of people standing around a fire in a circle",
#     "a group of children playing with hula hoops",
#     "a large red sculpture is in the middle of a crowd"

# ]

# brief@30
# labels = [
#     "A blend of serene strings and deep, resonant tones captures the vastness and grandeur of the scene, with occasional crescendos mirroring the crashing waves below, evoking awe and contemplation.",
#     "A tranquil yet vibrant melody emerges, blending soft, flowing tones to reflect the serenity of the wetland, punctuated by gentle percussion mimicking the rustling of reeds and the trickle of water.",
#     "A lively, upbeat composition with a mix of traditional and modern instruments, featuring catchy melodies and rhythms that mirror the energetic and joyful movements of the dancers in blue and white.",
#     "A gentle, rhythmic composition featuring deep, resonant tones to mirror the elephants' slow, deliberate movements. Soft percussion and serene melodies evoke the peaceful atmosphere of the zoo enclosure.",
#     "A whimsical, light-hearted melody featuring flute and strings, mimicking the gentle sway of plants in the breeze and the playful shapes of cartoon clouds floating across a bright, sunny sky.",
#     "A majestic orchestral piece with deep, resonant brass and sweeping strings, capturing the grandeur and gentle majesty of elephants in their natural habitat, evoking a sense of wonder and reverence.",
#     "A gentle, dreamy piece featuring soft piano and ethereal strings, capturing the calming essence of lavender flowers swaying in a gentle breeze, evoking a sense of tranquility and peacefulness.",
#     "A grand orchestral piece with deep, rumbling bass representing the towering peaks, accompanied by soaring strings and brass depicting the majesty and awe-inspiring beauty of the mountain range.",
#     "A symphony of bubbling anticipation builds as Old Faithful's steamy crescendo erupts, punctuating the air with rhythmic bursts of water and minerals, creating a natural percussion of geothermal power.",
#     "A grand orchestral piece with strong brass and percussion, evoking a sense of awe and majesty, mirroring the stadium's illuminated grandeur against the night sky.",
#     "The music starts softly, mimicking the crackling of the fire, gradually building with tribal drums and chants, evoking a sense of unity, storytelling, and ancient rituals.",
#     "A lively, playful piece with bouncy rhythms and bright melodies, mimicking the joyous energy of children. Instruments like xylophones, flutes, and light percussion create a fun, carefree atmosphere.",
#     "A rhythmic, pulsating composition, with deep bass tones and sharp, metallic sounds, reflecting the sculpture's imposing presence and the energetic buzz of the surrounding crowd."

# ]

# Long@50
labels = [
    "The music begins with soft, distant waves crashing against the rocks, conveying the vastness of the ocean. As the man gazes out, a haunting melody emerges from the depths, blending with the sounds of seagulls and the wind. The music builds, echoing the man's contemplation and the grandeur of nature.",
    "A tranquil melody featuring gentle piano and soft strings, mimicking the serenity of the wetland. The music starts with a simple, repetitive motif, representing the steady flow of the water. As the piece progresses, subtle bird calls and rustling reeds are woven in, adding depth and a sense of natural beauty.",
    "For a group of people dressed in blue and white dancing, the music could reflect a sense of unity and celebration. Imagine a lively rhythm with elements of folk music, perhaps incorporating instruments like tambourines and flutes to create a festive and communal atmosphere. The melody could be uplifting, encouraging listeners to join the dance.",
    "The music starts with deep, resonant notes, mimicking the elephants' heavy footsteps. As they walk, lighter, more playful melodies join in, reflecting their curious interactions with each other and their environment. The composition builds to a crescendo, symbolizing the majesty and grace of these magnificent creatures.",
    "A whimsical melody emerges, echoing the playful dance of animated clouds drifting lazily over a vibrant, bustling garden. Gentle strings mimic the breeze rustling through leaves, while flutes and chimes mimic the chatter of animated plants. The music builds, mirroring the growing energy of a magical world filled with life and wonder.",
    "A majestic orchestral piece capturing the grandeur of elephants in the wild. The music starts with a gentle, mysterious melody to represent the vastness of their habitat. As the footage shows the elephants roaming freely, the music builds to powerful, uplifting themes, symbolizing their strength, resilience, and the beauty of their natural environment.",
    "Imagine a tranquil piece where delicate piano melodies flutter like butterflies over soft, sustained strings. The music ebbs and flows like a gentle breeze through a lavender field, evoking a sense of peace and calm. Subtle harp glissandos and light percussion add a touch of whimsy, mirroring the flowers' graceful dance in the wind.",
    "A solemn piano melody echoing the grandeur of towering peaks, with deep bass notes mirroring the rugged terrain. Ethereal strings evoke swirling mists, and occasional percussion mimics distant avalanches. The music builds to a crescendo, symbolizing the triumph of reaching the summit, before fading into a reflective, peaceful outro.",
    "A grand orchestral piece captures the majesty of Yellowstone's Old Faithful erupting, starting with soft strings and woodwinds building anticipation like steam rising. As the geyser spouts, brass and percussion explode into a triumphant melody, mirroring the geyser's powerful display, before settling into a serene, reflective coda as the eruption subsides.",
    "A grand orchestral piece captures the majesty of the Olympic stadium at night. Bold brass fanfares announce the stadium's presence, while strings and percussion create a sense of excitement and anticipation. As the music builds, it conveys the spirit of competition and the thrill of athletic achievement under the stadium's dazzling lights.",
    "The music could start with soft, ambient sounds evoking the crackling of the fire and gentle murmurs of conversation. As the scene intensifies, drums and rhythmic instruments join, mimicking the heartbeat of the group. Melodic elements could represent each person's unique energy, blending into a harmonious, communal theme.",
    "The music could start with light, playful melodies mimicking the cheerful laughter of children. As the hula hooping intensifies, the tempo picks up, adding energetic percussion to match their movements. A catchy, repetitive motif could symbolize the rhythmic motion of the hoops, creating a fun and lively composition.",
    "The music starts with deep, resonant tones to reflect the grandeur of the sculpture. As the crowd moves around it, the music shifts to a rhythmic pattern, mirroring the movement and energy of the people. Gradually, the music builds to a crescendo, symbolizing the collective awe and admiration for the artwork."

]

print(len(labels))
labels
# Out:
# 13
# ["The music begins with soft, distant waves crashing against the rocks, conveying the vastness of the ocean. As the man gazes out, a haunting melody emerges from the depths, blending with the sounds of seagulls and the wind. The music builds, echoing the man's contemplation and the grandeur of nature.",
#  'A tranquil melody featuring gentle piano and soft strings, mimicking the serenity of the wetland. The music starts with a simple, repetitive motif, representing the steady flow of the water. As the piece progresses, subtle bird calls and rustling reeds are woven in, adding depth and a sense of natural beauty.',
#  'For a group of people dressed in blue and white dancing, the music could reflect a sense of unity and celebration. Imagine a lively rhythm with elements of folk music, perhaps incorporating instruments like tambourines and flutes to create a festive and communal atmosphere. The melody could be uplifting, encouraging listeners to join the dance.',
# ...

# %%
# !pip install decord
import decord

from decord import VideoReader

music_num_list = []
music_labels = []
for video_fname in mp4_files:
  vr = VideoReader(video_fname)
  frame = vr[100]
  frame_values = frame.asnumpy()
  im = Image.fromarray(frame_values)
  max_label, max_label_num = classify(im, labels)
  music_labels.append(max_label)
  music_num_list.append(max_label_num)

# %%
for sentence in music_labels:
  print(sentence)
# Out:
# The music starts with deep, resonant notes, mimicking the elephants' heavy footsteps. As they walk, lighter, more playful melodies join in, reflecting their curious interactions with each other and their environment. The composition builds to a crescendo, symbolizing the majesty and grace of these magnificent creatures.
# The music could start with light, playful melodies mimicking the cheerful laughter of children. As the hula hooping intensifies, the tempo picks up, adding energetic percussion to match their movements. A catchy, repetitive motif could symbolize the rhythmic motion of the hoops, creating a fun and lively composition.
# ...

# %%
music_num_list
# Out:
# [3, 11, 8, 10, 11, 4, 7, 1, 10, 1, 0, 10, 11]

# %%
questions = []
for i in music_num_list:
  print(mp3_files[i])
  questions.append(mp3_files[i])
# Out:
# Q5_10sec.mp3
# Q80_10sec.mp3
# Q66_10sec.mp3
# Q77_10sec.mp3
# Q80_10sec.mp3
# Q13_10sec.mp3
# Q39_10sec.mp3
# Q2_10sec.mp3
# Q77_10sec.mp3
# Q2_10sec.mp3
# Q1_10sec.mp3
# Q77_10sec.mp3
# Q80_10sec.mp3

# %%
new_questions = []
for question in questions:
  new_questions.append(question.replace("_10sec.mp3", ""))
questions = new_questions

for i in range(len(questions)):
  print(questions[i])
# Out:
# Q5
# Q80
# Q66
# Q77
# Q80
# Q13
# Q39
# Q2
# Q77
# Q2
# Q1
# Q77
# Q80

# %%
# mp3_files_formal = [file.replace(" ", "\ ") for file in music_list]
# mp3_files_formal
# Out:
# ['Friction\\ Looks.mp3',
#  'Kittens\\ Caprice.mp3',
#  'Night\\ Music.mp3',
#  'MoonForest\\ inst.mp3',
#  'MoonForest\\ inst.mp3',
#  'Very\\ Right.mp3',
#  'MoonForest\\ inst.mp3',
#  'Bewitched\\ Forest.mp3',
#  'Friction\\ Looks.mp3',
#  'Dawning\\ Tale.mp3',
#  'Bygone\\ Era.mp3',
#  'Kittens\\ Caprice.mp3',
#  'Friction\\ Looks.mp3',
#  'Friction\\ Looks.mp3']

# %%
for i in range(len(mp4_files)):
  # !ffmpeg -i Q300001.mp4 -i cliff_30sec.mp3 -c copy -shortest output.mp4
  # !ffmpeg -i {mp4_files[i]} -i {music_list[i]} -c copy -map 0:v:0 -map 1:a:0 output{i}.mp4
  # !ffmpeg -i {mp4_files[i]} -i {mp3_files[music_num_list[i]]} -c copy -shortest normal_clip10_des_30new_{i}.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
